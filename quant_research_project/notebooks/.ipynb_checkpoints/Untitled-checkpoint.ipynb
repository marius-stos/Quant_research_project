# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
import backtrader as bt

# set browser full width (fix import for Python 3.12)
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

class BollingerBands(bt.Strategy):
    params = (
        ('n', 20),
        ('ndev', 2.0),
        ('printlog', False),
    )

    def __init__(self):
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.bar_executed = None
        self.val_start = None
        self.dataclose = self.datas[0].close
        self.bollinger = bt.indicators.BollingerBands(self.dataclose, period=self.params.n, devfactor=self.params.ndev)
        self.mb = self.bollinger.mid
        self.ub = self.bollinger.top
        self.lb = self.bollinger.bot

    def log(self, txt, dt=None, doprint=False):
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def start(self):
        self.val_start = self.broker.get_cash()

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' % (trade.pnl, trade.pnlcomm))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Size: %.0f, Cost: %.2f, Comm %.2f, RemSize: %.0f, RemCash: %.2f' %
                    (order.executed.price,
                     order.executed.size,
                     order.executed.value,
                     order.executed.comm,
                     order.executed.remsize,
                     self.broker.get_cash()))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:
                self.log('SELL EXECUTED, Price: %.2f, Size: %.0f, Cost: %.2f, Comm %.2f, RemSize: %.0f, RemCash: %.2f' %
                         (order.executed.price,
                          order.executed.size,
                          order.executed.value,
                          order.executed.comm,
                          order.executed.remsize,
                          self.broker.get_cash()))
            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Expired, order.Margin, order.Rejected]:
            self.log('Order Failed')

        self.order = None

    def next(self):
        if self.order:
            return

        if np.count_nonzero(~np.isnan(self.mb.get(0, len(self.mb)))) == 1:
            return

        if self.position.size <= 0 \
                and self.dataclose[0] > self.lb[0] \
                and self.dataclose[-1] < self.lb[-1]:
            self.order = self.buy()

        elif self.position.size >= 0 \
                and self.dataclose[0] < self.ub[0] \
                and self.dataclose[-1] > self.ub[-1]:
            self.order = self.sell()

        elif self.dataclose[0] < self.mb[0] and self.position.size < 0:
            self.order = self.buy()

        elif self.dataclose[0] > self.mb[0] and self.position.size > 0:
            self.order = self.sell()

    def stop(self):
        roi = (self.broker.get_value() / self.val_start) - 1.0
        self.log('ROI: {:.2f}%'.format(100.0 * roi))
        self.log('(Bollinger params (%2d, %2d)) Ending Value %.2f' %
                 (self.params.n, self.params.ndev, self.broker.getvalue()), doprint=True)


if __name__ == '__main__':
    param_opt = False
    perf_eval = True
    benchmark = 'SPX'

    cerebro = bt.Cerebro()

    # 
    datapath = "/Users/mariusstos/quant_research_project/data/SPX.csv"

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname=datapath,
        fromdate=datetime(2010, 1, 1),
        todate=datetime(2019, 12, 31),
        reverse=False)

    cerebro.adddata(data)
    cerebro.broker.setcash(100000.0)
    cerebro.addsizer(bt.sizers.PercentSizerInt, percents=95)
    cerebro.broker.setcommission(commission=0.001)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    if param_opt:
        cerebro.optstrategy(BollingerBands, n=[10, 20], ndev=[2.0, 2.5])
        perf_eval = False
    else:
        cerebro.addstrategy(BollingerBands, n=20, ndev=2.0, printlog=True)

    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='SharpeRatio')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='DrawDown')
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

    results = cerebro.run()
    strat = results[0]

    print('Final Portfolio Value: %.2f, Sharpe Ratio: %.2f, DrawDown: %.2f, MoneyDown %.2f' %
          (cerebro.broker.getvalue(),
           strat.analyzers.SharpeRatio.get_analysis()['sharperatio'],
           strat.analyzers.DrawDown.get_analysis()['drawdown'],
           strat.analyzers.DrawDown.get_analysis()['moneydown']))

    if perf_eval:
        import matplotlib.pyplot as plt
        cerebro.plot(style='candlestick')
        plt.show()
# Out:
# <style>.container { width:100% !important; }</style>
# Starting Portfolio Value: 100000.00
# 2010-04-19, SELL EXECUTED, Price: 1192.06, Size: -79, Cost: -94172.74, Comm 94.17, RemSize: 0, RemCash: 194078.57
# 2010-04-28, BUY EXECUTED, Price: 1184.59, Size: 79, Cost: -94172.74, Comm 93.58, RemSize: 0, RemCash: 100402.37
# 2010-04-28, OPERATION PROFIT, GROSS 590.13, NET 402.37
# 2010-05-11, BUY EXECUTED, Price: 1156.39, Size: 82, Cost: 94823.98, Comm 94.82, RemSize: 0, RemCash: 5483.57
# 2010-06-14, SELL EXECUTED, Price: 1095.00, Size: -82, Cost: 94823.98, Comm 89.79, RemSize: 0, RemCash: 95183.78
# 2010-06-14, OPERATION PROFIT, GROSS -5033.98, NET -5218.59
# 2010-07-02, BUY EXECUTED, Price: 1027.65, Size: 88, Cost: 90433.20, Comm 90.43, RemSize: 0, RemCash: 4660.15
# 2010-07-12, SELL EXECUTED, Price: 1077.23, Size: -88, Cost: 90433.20, Comm 94.80, RemSize: 0, RemCash: 99361.59
# 2010-07-12, OPERATION PROFIT, GROSS 4363.04, NET 4177.81
# 2010-08-26, BUY EXECUTED, Price: 1056.28, Size: 89, Cost: 94008.92, Comm 94.01, RemSize: 0, RemCash: 5258.66
# 2010-09-03, SELL EXECUTED, Price: 1093.61, Size: -89, Cost: 94008.92, Comm 97.33, RemSize: 0, RemCash: 102492.62
# 2010-09-03, OPERATION PROFIT, GROSS 3322.37, NET 3131.03
# 2010-10-15, SELL EXECUTED, Price: 1177.47, Size: -82, Cost: -96552.54, Comm 96.55, RemSize: 0, RemCash: 198948.61
# 2010-11-17, BUY EXECUTED, Price: 1178.33, Size: 82, Cost: -96552.54, Comm 96.62, RemSize: 0, RemCash: 102228.93
# 2010-11-17, OPERATION PROFIT, GROSS -70.52, NET -263.70
# 2011-01-20, SELL EXECUTED, Price: 1280.85, Size: -75, Cost: -96063.75, Comm 96.06, RemSize: 0, RemCash: 198196.61
# 2011-01-31, BUY EXECUTED, Price: 1276.50, Size: 75, Cost: -96063.75, Comm 95.74, RemSize: 0, RemCash: 102363.37
# 2011-01-31, OPERATION PROFIT, GROSS 326.25, NET 134.45
# 2011-02-03, SELL EXECUTED, Price: 1302.77, Size: -74, Cost: -96404.98, Comm 96.40, RemSize: 0, RemCash: 198671.95
# 2011-02-24, BUY EXECUTED, Price: 1307.09, Size: 74, Cost: -96404.98, Comm 96.72, RemSize: 0, RemCash: 101850.56
# 2011-02-24, OPERATION PROFIT, GROSS -319.68, NET -512.81
# 2011-03-14, BUY EXECUTED, Price: 1301.19, Size: 74, Cost: 96288.06, Comm 96.29, RemSize: 0, RemCash: 5466.22
# 2011-03-25, SELL EXECUTED, Price: 1311.80, Size: -74, Cost: 96288.06, Comm 97.07, RemSize: 0, RemCash: 102442.34
# 2011-03-25, OPERATION PROFIT, GROSS 785.14, NET 591.78
# 2011-05-03, SELL EXECUTED, Price: 1359.76, Size: -71, Cost: -96542.96, Comm 96.54, RemSize: 0, RemCash: 198888.76
# 2011-05-16, BUY EXECUTED, Price: 1334.77, Size: 71, Cost: -96542.96, Comm 94.77, RemSize: 0, RemCash: 104025.32
# 2011-05-16, OPERATION PROFIT, GROSS 1774.29, NET 1582.98
# 2011-05-25, BUY EXECUTED, Price: 1316.36, Size: 75, Cost: 98727.00, Comm 98.73, RemSize: 0, RemCash: 5199.59
# 2011-06-01, SELL EXECUTED, Price: 1345.20, Size: -75, Cost: 98727.00, Comm 100.89, RemSize: 0, RemCash: 105988.70
# 2011-06-01, OPERATION PROFIT, GROSS 2163.00, NET 1963.38
# 2011-06-10, BUY EXECUTED, Price: 1288.60, Size: 78, Cost: 100510.80, Comm 100.51, RemSize: 0, RemCash: 5377.39
# 2011-06-29, SELL EXECUTED, Price: 1296.85, Size: -78, Cost: 100510.80, Comm 101.15, RemSize: 0, RemCash: 106430.54
# 2011-06-29, OPERATION PROFIT, GROSS 643.50, NET 441.83
# 2011-07-07, SELL EXECUTED, Price: 1339.62, Size: -75, Cost: -100471.50, Comm 100.47, RemSize: 0, RemCash: 206801.57
# 2011-07-19, BUY EXECUTED, Price: 1307.07, Size: 75, Cost: -100471.50, Comm 98.03, RemSize: 0, RemCash: 108673.29
# 2011-07-19, OPERATION PROFIT, GROSS 2441.25, NET 2242.75
# 2011-08-10, BUY EXECUTED, Price: 1171.77, Size: 88, Cost: 103115.76, Comm 103.12, RemSize: 0, RemCash: 5454.41
# 2011-08-30, SELL EXECUTED, Price: 1209.76, Size: -88, Cost: 103115.76, Comm 106.46, RemSize: 0, RemCash: 111806.83
# 2011-08-30, OPERATION PROFIT, GROSS 3343.12, NET 3133.55
# 2011-09-26, BUY EXECUTED, Price: 1136.91, Size: 93, Cost: 105732.63, Comm 105.73, RemSize: 0, RemCash: 5968.47
# 2011-10-07, SELL EXECUTED, Price: 1165.03, Size: -93, Cost: 105732.63, Comm 108.35, RemSize: 0, RemCash: 114207.91
# 2011-10-07, OPERATION PROFIT, GROSS 2615.16, NET 2401.08
# 2011-11-29, BUY EXECUTED, Price: 1192.56, Size: 90, Cost: 107330.40, Comm 107.33, RemSize: 0, RemCash: 6770.18
# 2011-12-01, SELL EXECUTED, Price: 1246.91, Size: -90, Cost: 107330.40, Comm 112.22, RemSize: 0, RemCash: 118879.86
# 2011-12-01, OPERATION PROFIT, GROSS 4891.50, NET 4671.95
# 2012-02-07, SELL EXECUTED, Price: 1344.33, Size: -84, Cost: -112923.72, Comm 112.92, RemSize: 0, RemCash: 231690.66
# 2012-03-07, BUY EXECUTED, Price: 1343.39, Size: 84, Cost: -112923.72, Comm 112.84, RemSize: 0, RemCash: 118733.05
# 2012-03-07, OPERATION PROFIT, GROSS 78.96, NET -146.81
# 2012-03-21, SELL EXECUTED, Price: 1405.52, Size: -80, Cost: -112441.60, Comm 112.44, RemSize: 0, RemCash: 231062.21
# 2012-04-05, BUY EXECUTED, Price: 1398.79, Size: 80, Cost: -112441.60, Comm 111.90, RemSize: 0, RemCash: 119047.11
# 2012-04-05, OPERATION PROFIT, GROSS 538.40, NET 314.06
# 2012-04-13, BUY EXECUTED, Price: 1387.61, Size: 81, Cost: 112396.41, Comm 112.40, RemSize: 0, RemCash: 6538.30
# 2012-04-26, SELL EXECUTED, Price: 1390.64, Size: -81, Cost: 112396.41, Comm 112.64, RemSize: 0, RemCash: 119067.50
# 2012-04-26, OPERATION PROFIT, GROSS 245.43, NET 20.39
# 2012-05-22, BUY EXECUTED, Price: 1316.09, Size: 85, Cost: 111867.65, Comm 111.87, RemSize: 0, RemCash: 7087.98
# 2012-06-11, SELL EXECUTED, Price: 1325.72, Size: -85, Cost: 111867.65, Comm 112.69, RemSize: 0, RemCash: 119661.50
# 2012-06-11, OPERATION PROFIT, GROSS 818.55, NET 594.00
# 2012-06-21, SELL EXECUTED, Price: 1355.43, Size: -83, Cost: -112500.69, Comm 112.50, RemSize: 0, RemCash: 232049.68
# 2012-06-26, BUY EXECUTED, Price: 1314.09, Size: 83, Cost: -112500.69, Comm 109.07, RemSize: 0, RemCash: 122871.14
# 2012-06-26, OPERATION PROFIT, GROSS 3431.22, NET 3209.65
# 2012-07-06, SELL EXECUTED, Price: 1367.09, Size: -85, Cost: -116202.65, Comm 116.20, RemSize: 0, RemCash: 238957.59
# 2012-07-11, BUY EXECUTED, Price: 1341.40, Size: 85, Cost: -116202.65, Comm 114.02, RemSize: 0, RemCash: 124824.57
# 2012-07-11, OPERATION PROFIT, GROSS 2183.65, NET 1953.43
# 2012-07-31, SELL EXECUTED, Price: 1385.27, Size: -85, Cost: -117747.95, Comm 117.75, RemSize: 0, RemCash: 242454.78
# 2012-08-31, BUY EXECUTED, Price: 1400.07, Size: 85, Cost: -117747.95, Comm 119.01, RemSize: 0, RemCash: 123329.82
# 2012-08-31, OPERATION PROFIT, GROSS -1258.00, NET -1494.75
# 2012-09-11, SELL EXECUTED, Price: 1429.13, Size: -81, Cost: -115759.53, Comm 115.76, RemSize: 0, RemCash: 238973.59
# 2012-09-27, BUY EXECUTED, Price: 1433.36, Size: 81, Cost: -115759.53, Comm 116.10, RemSize: 0, RemCash: 122755.33
# 2012-09-27, OPERATION PROFIT, GROSS -342.63, NET -574.49
# 2012-10-26, BUY EXECUTED, Price: 1412.97, Size: 82, Cost: 115863.54, Comm 115.86, RemSize: 0, RemCash: 6775.92
# 2012-11-26, SELL EXECUTED, Price: 1409.15, Size: -82, Cost: 115863.54, Comm 115.55, RemSize: 0, RemCash: 122210.67
# 2012-11-26, OPERATION PROFIT, GROSS -313.24, NET -544.65
# 2012-12-20, SELL EXECUTED, Price: 1435.81, Size: -80, Cost: -114864.80, Comm 114.86, RemSize: 0, RemCash: 236960.61
# 2012-12-27, BUY EXECUTED, Price: 1419.83, Size: 80, Cost: -114864.80, Comm 113.59, RemSize: 0, RemCash: 123260.62
# 2012-12-27, OPERATION PROFIT, GROSS 1278.40, NET 1049.95
# 2013-01-08, SELL EXECUTED, Price: 1461.89, Size: -80, Cost: -116951.20, Comm 116.95, RemSize: 0, RemCash: 240094.87
# 2013-02-22, BUY EXECUTED, Price: 1502.42, Size: 80, Cost: -116951.20, Comm 120.19, RemSize: 0, RemCash: 119781.08
# 2013-02-22, OPERATION PROFIT, GROSS -3242.40, NET -3479.54
# 2013-02-27, BUY EXECUTED, Price: 1496.94, Size: 76, Cost: 113767.44, Comm 113.77, RemSize: 0, RemCash: 5899.87
# 2013-02-28, SELL EXECUTED, Price: 1515.99, Size: -76, Cost: 113767.44, Comm 115.22, RemSize: 0, RemCash: 120999.90
# 2013-02-28, OPERATION PROFIT, GROSS 1447.80, NET 1218.82
# 2013-03-08, SELL EXECUTED, Price: 1544.26, Size: -74, Cost: -114275.24, Comm 114.28, RemSize: 0, RemCash: 235160.86
# 2013-04-04, BUY EXECUTED, Price: 1553.69, Size: 74, Cost: -114275.24, Comm 114.97, RemSize: 0, RemCash: 120072.83
# 2013-04-04, OPERATION PROFIT, GROSS -697.82, NET -927.07
# 2013-04-15, SELL EXECUTED, Price: 1588.84, Size: -71, Cost: -112807.64, Comm 112.81, RemSize: 0, RemCash: 232767.66
# 2013-04-16, BUY EXECUTED, Price: 1552.36, Size: 71, Cost: -112807.64, Comm 110.22, RemSize: 0, RemCash: 122439.88
# 2013-04-16, OPERATION PROFIT, GROSS 2590.08, NET 2367.05
# 2013-05-07, SELL EXECUTED, Price: 1617.55, Size: -71, Cost: -114846.05, Comm 114.85, RemSize: 0, RemCash: 237171.09
# 2013-06-03, BUY EXECUTED, Price: 1631.71, Size: 71, Cost: -114846.05, Comm 115.85, RemSize: 0, RemCash: 121203.82
# 2013-06-03, OPERATION PROFIT, GROSS -1005.36, NET -1236.06
# 2013-06-07, BUY EXECUTED, Price: 1625.27, Size: 70, Cost: 113768.90, Comm 113.77, RemSize: 0, RemCash: 7321.16
# 2013-06-19, SELL EXECUTED, Price: 1651.83, Size: -70, Cost: 113768.90, Comm 115.63, RemSize: 0, RemCash: 122833.63
# 2013-06-19, OPERATION PROFIT, GROSS 1859.20, NET 1629.80
# 2013-06-26, BUY EXECUTED, Price: 1592.27, Size: 73, Cost: 116235.71, Comm 116.24, RemSize: 0, RemCash: 6481.68
# 2013-07-08, SELL EXECUTED, Price: 1634.20, Size: -73, Cost: 116235.71, Comm 119.30, RemSize: 0, RemCash: 125658.98
# 2013-07-08, OPERATION PROFIT, GROSS 3060.89, NET 2825.36
# 2013-07-15, SELL EXECUTED, Price: 1679.59, Size: -71, Cost: -119250.89, Comm 119.25, RemSize: 0, RemCash: 244790.62
# 2013-08-12, BUY EXECUTED, Price: 1688.37, Size: 71, Cost: -119250.89, Comm 119.87, RemSize: 0, RemCash: 124796.48
# 2013-08-12, OPERATION PROFIT, GROSS -623.38, NET -862.51
# 2013-08-21, BUY EXECUTED, Price: 1650.66, Size: 71, Cost: 117196.86, Comm 117.20, RemSize: 0, RemCash: 7482.42
# 2013-09-10, SELL EXECUTED, Price: 1675.11, Size: -71, Cost: 117196.86, Comm 118.93, RemSize: 0, RemCash: 126296.30
# 2013-09-10, OPERATION PROFIT, GROSS 1735.95, NET 1499.82
# 2013-09-13, SELL EXECUTED, Price: 1685.04, Size: -71, Cost: -119637.84, Comm 119.64, RemSize: 0, RemCash: 245814.50
# 2013-10-01, BUY EXECUTED, Price: 1682.41, Size: 71, Cost: -119637.84, Comm 119.45, RemSize: 0, RemCash: 126243.94
# 2013-10-01, OPERATION PROFIT, GROSS 186.73, NET -52.36
# 2013-10-11, BUY EXECUTED, Price: 1691.09, Size: 70, Cost: 118376.30, Comm 118.38, RemSize: 0, RemCash: 7749.26
# 2013-10-14, SELL EXECUTED, Price: 1699.86, Size: -70, Cost: 118376.30, Comm 118.99, RemSize: 0, RemCash: 126620.47
# 2013-10-14, OPERATION PROFIT, GROSS 613.90, NET 376.53
# 2013-10-22, SELL EXECUTED, Price: 1746.48, Size: -68, Cost: -118760.64, Comm 118.76, RemSize: 0, RemCash: 245262.35
# 2013-12-06, BUY EXECUTED, Price: 1788.36, Size: 68, Cost: -118760.64, Comm 121.61, RemSize: 0, RemCash: 123532.27
# 2013-12-06, OPERATION PROFIT, GROSS -2847.84, NET -3088.21
# 2013-12-16, BUY EXECUTED, Price: 1777.48, Size: 66, Cost: 117313.68, Comm 117.31, RemSize: 0, RemCash: 6101.27
# 2013-12-19, SELL EXECUTED, Price: 1809.00, Size: -66, Cost: 117313.68, Comm 119.39, RemSize: 0, RemCash: 125375.88
# 2013-12-19, OPERATION PROFIT, GROSS 2080.32, NET 1843.61
# 2013-12-30, SELL EXECUTED, Price: 1841.47, Size: -64, Cost: -117854.08, Comm 117.85, RemSize: 0, RemCash: 243112.10
# 2014-01-14, BUY EXECUTED, Price: 1821.36, Size: 64, Cost: -117854.08, Comm 116.57, RemSize: 0, RemCash: 126428.50
# 2014-01-14, OPERATION PROFIT, GROSS 1287.04, NET 1052.62
# 2014-01-29, BUY EXECUTED, Price: 1790.15, Size: 67, Cost: 119940.05, Comm 119.94, RemSize: 0, RemCash: 6368.51
# 2014-02-12, SELL EXECUTED, Price: 1820.12, Size: -67, Cost: 119940.05, Comm 121.95, RemSize: 0, RemCash: 128194.60
# 2014-02-12, OPERATION PROFIT, GROSS 2007.99, NET 1766.10
# 2014-04-15, BUY EXECUTED, Price: 1831.45, Size: 66, Cost: 120875.70, Comm 120.88, RemSize: 0, RemCash: 7198.02
# 2014-04-17, SELL EXECUTED, Price: 1861.73, Size: -66, Cost: 120875.70, Comm 122.87, RemSize: 0, RemCash: 129949.33
# 2014-04-17, OPERATION PROFIT, GROSS 1998.48, NET 1754.73
# 2014-05-29, SELL EXECUTED, Price: 1910.60, Size: -64, Cost: -122278.40, Comm 122.28, RemSize: 0, RemCash: 252105.45
# 2014-07-18, BUY EXECUTED, Price: 1961.54, Size: 64, Cost: -122278.40, Comm 125.54, RemSize: 0, RemCash: 126441.35
# 2014-07-18, OPERATION PROFIT, GROSS -3260.16, NET -3507.98
# 2014-08-05, BUY EXECUTED, Price: 1936.34, Size: 61, Cost: 118116.74, Comm 118.12, RemSize: 0, RemCash: 8206.49
# 2014-08-15, SELL EXECUTED, Price: 1958.87, Size: -61, Cost: 118116.74, Comm 119.49, RemSize: 0, RemCash: 127578.07
# 2014-08-15, OPERATION PROFIT, GROSS 1374.33, NET 1136.72
# 2014-09-22, SELL EXECUTED, Price: 2009.08, Size: -60, Cost: -120544.80, Comm 120.54, RemSize: 0, RemCash: 248002.33
# 2014-09-23, BUY EXECUTED, Price: 1992.78, Size: 60, Cost: -120544.80, Comm 119.57, RemSize: 0, RemCash: 128315.96
# 2014-09-23, OPERATION PROFIT, GROSS 978.00, NET 737.89
# 2014-09-29, BUY EXECUTED, Price: 1978.96, Size: 61, Cost: 120716.56, Comm 120.72, RemSize: 0, RemCash: 7478.69
# 2014-10-22, SELL EXECUTED, Price: 1941.29, Size: -61, Cost: 120716.56, Comm 118.42, RemSize: 0, RemCash: 125778.96
# 2014-10-22, OPERATION PROFIT, GROSS -2297.87, NET -2537.01
# 2014-12-12, BUY EXECUTED, Price: 2030.36, Size: 58, Cost: 117760.88, Comm 117.76, RemSize: 0, RemCash: 7900.32
# 2014-12-19, SELL EXECUTED, Price: 2061.04, Size: -58, Cost: 117760.88, Comm 119.54, RemSize: 0, RemCash: 127321.10
# 2014-12-19, OPERATION PROFIT, GROSS 1779.44, NET 1542.14
# 2015-03-13, BUY EXECUTED, Price: 2064.56, Size: 58, Cost: 119744.48, Comm 119.74, RemSize: 0, RemCash: 7456.87
# 2015-03-19, SELL EXECUTED, Price: 2098.69, Size: -58, Cost: 119744.48, Comm 121.72, RemSize: 0, RemCash: 129059.17
# 2015-03-19, OPERATION PROFIT, GROSS 1979.54, NET 1738.07
# 2015-06-10, BUY EXECUTED, Price: 2081.12, Size: 58, Cost: 120704.96, Comm 120.70, RemSize: 0, RemCash: 8233.50
# 2015-06-19, SELL EXECUTED, Price: 2121.06, Size: -58, Cost: 120704.96, Comm 123.02, RemSize: 0, RemCash: 131131.96
# 2015-06-19, OPERATION PROFIT, GROSS 2316.52, NET 2072.79
# 2015-07-01, BUY EXECUTED, Price: 2067.00, Size: 60, Cost: 124020.00, Comm 124.02, RemSize: 0, RemCash: 6987.94
# 2015-07-14, SELL EXECUTED, Price: 2099.72, Size: -60, Cost: 124020.00, Comm 125.98, RemSize: 0, RemCash: 132845.16
# 2015-07-14, OPERATION PROFIT, GROSS 1963.20, NET 1713.20
# 2015-08-27, BUY EXECUTED, Price: 1942.77, Size: 65, Cost: 126280.05, Comm 126.28, RemSize: 0, RemCash: 6438.83
# 2015-09-16, SELL EXECUTED, Price: 1978.02, Size: -65, Cost: 126280.05, Comm 128.57, RemSize: 0, RemCash: 134881.56
# 2015-09-16, OPERATION PROFIT, GROSS 2291.25, NET 2036.40
# 2015-10-01, BUY EXECUTED, Price: 1919.65, Size: 66, Cost: 126696.90, Comm 126.70, RemSize: 0, RemCash: 8057.96
# 2015-10-05, SELL EXECUTED, Price: 1954.33, Size: -66, Cost: 126696.90, Comm 128.99, RemSize: 0, RemCash: 136914.75
# 2015-10-05, OPERATION PROFIT, GROSS 2288.88, NET 2033.20
# 2015-12-15, BUY EXECUTED, Price: 2025.55, Size: 64, Cost: 129635.20, Comm 129.64, RemSize: 0, RemCash: 7149.92
# 2015-12-17, SELL EXECUTED, Price: 2073.76, Size: -64, Cost: 129635.20, Comm 132.72, RemSize: 0, RemCash: 139737.84
# 2015-12-17, OPERATION PROFIT, GROSS 3085.44, NET 2823.08
# 2015-12-22, BUY EXECUTED, Price: 2023.15, Size: 65, Cost: 131504.75, Comm 131.50, RemSize: 0, RemCash: 8101.58
# 2015-12-24, SELL EXECUTED, Price: 2063.52, Size: -65, Cost: 131504.75, Comm 134.13, RemSize: 0, RemCash: 142096.25
# 2015-12-24, OPERATION PROFIT, GROSS 2624.05, NET 2358.42
# 2016-01-13, BUY EXECUTED, Price: 1940.34, Size: 69, Cost: 133883.46, Comm 133.88, RemSize: 0, RemCash: 8078.91
# 2016-02-01, SELL EXECUTED, Price: 1936.94, Size: -69, Cost: 133883.46, Comm 133.65, RemSize: 0, RemCash: 141594.12
# 2016-02-01, OPERATION PROFIT, GROSS -234.60, NET -502.13
# 2016-04-15, SELL EXECUTED, Price: 2083.10, Size: -64, Cost: -133318.40, Comm 133.32, RemSize: 0, RemCash: 274779.20
# 2016-04-29, BUY EXECUTED, Price: 2071.82, Size: 64, Cost: -133318.40, Comm 132.60, RemSize: 0, RemCash: 142050.13
# 2016-04-29, OPERATION PROFIT, GROSS 721.92, NET 456.01
# 2016-05-27, SELL EXECUTED, Price: 2090.06, Size: -64, Cost: -133763.84, Comm 133.76, RemSize: 0, RemCash: 275680.20
# 2016-06-14, BUY EXECUTED, Price: 2076.65, Size: 64, Cost: -133763.84, Comm 132.91, RemSize: 0, RemCash: 142641.70
# 2016-06-14, OPERATION PROFIT, GROSS 858.24, NET 591.57
# 2016-06-29, BUY EXECUTED, Price: 2042.69, Size: 66, Cost: 134817.54, Comm 134.82, RemSize: 0, RemCash: 7689.34
# 2016-07-01, SELL EXECUTED, Price: 2099.34, Size: -66, Cost: 134817.54, Comm 138.56, RemSize: 0, RemCash: 146107.22
# 2016-07-01, OPERATION PROFIT, GROSS 3738.90, NET 3465.53
# 2016-09-13, BUY EXECUTED, Price: 2150.47, Size: 64, Cost: 137630.08, Comm 137.63, RemSize: 0, RemCash: 8339.51
# 2016-09-22, SELL EXECUTED, Price: 2170.94, Size: -64, Cost: 137630.08, Comm 138.94, RemSize: 0, RemCash: 147140.73
# 2016-09-22, OPERATION PROFIT, GROSS 1310.08, NET 1033.51
# 2016-11-08, BUY EXECUTED, Price: 2129.92, Size: 65, Cost: 138444.80, Comm 138.44, RemSize: 0, RemCash: 8557.49
# 2016-11-09, SELL EXECUTED, Price: 2131.56, Size: -65, Cost: 138444.80, Comm 138.55, RemSize: 0, RemCash: 146970.34
# 2016-11-09, OPERATION PROFIT, GROSS 106.60, NET -170.40
# 2016-12-13, SELL EXECUTED, Price: 2263.32, Size: -61, Cost: -138062.52, Comm 138.06, RemSize: 0, RemCash: 284894.79
# 2017-01-03, BUY EXECUTED, Price: 2251.57, Size: 61, Cost: -138062.52, Comm 137.35, RemSize: 0, RemCash: 147411.68
# 2017-01-03, OPERATION PROFIT, GROSS 716.75, NET 441.34
# 2017-01-30, SELL EXECUTED, Price: 2286.01, Size: -61, Cost: -139446.61, Comm 139.45, RemSize: 0, RemCash: 286718.84
# 2017-03-15, BUY EXECUTED, Price: 2370.34, Size: 61, Cost: -139446.61, Comm 144.59, RemSize: 0, RemCash: 141983.51
# 2017-03-15, OPERATION PROFIT, GROSS -5144.13, NET -5428.17
# 2017-03-23, BUY EXECUTED, Price: 2345.97, Size: 57, Cost: 133720.29, Comm 133.72, RemSize: 0, RemCash: 8129.50
# 2017-03-31, SELL EXECUTED, Price: 2364.82, Size: -57, Cost: 133720.29, Comm 134.79, RemSize: 0, RemCash: 142789.45
# 2017-03-31, OPERATION PROFIT, GROSS 1074.45, NET 805.93
# 2017-04-18, BUY EXECUTED, Price: 2342.53, Size: 57, Cost: 133524.21, Comm 133.52, RemSize: 0, RemCash: 9131.71
# 2017-04-21, SELL EXECUTED, Price: 2354.74, Size: -57, Cost: 133524.21, Comm 134.22, RemSize: 0, RemCash: 143217.67
# 2017-04-21, OPERATION PROFIT, GROSS 695.97, NET 428.23
# 2017-04-28, SELL EXECUTED, Price: 2393.68, Size: -56, Cost: -134046.08, Comm 134.05, RemSize: 0, RemCash: 277129.71
# 2017-05-18, BUY EXECUTED, Price: 2354.69, Size: 56, Cost: -134046.08, Comm 131.86, RemSize: 0, RemCash: 145135.20
# 2017-05-18, OPERATION PROFIT, GROSS 2183.44, NET 1917.53
# 2017-06-06, SELL EXECUTED, Price: 2431.92, Size: -56, Cost: -136187.52, Comm 136.19, RemSize: 0, RemCash: 281186.54
# 2017-06-28, BUY EXECUTED, Price: 2428.70, Size: 56, Cost: -136187.52, Comm 136.01, RemSize: 0, RemCash: 145043.33
# 2017-06-28, OPERATION PROFIT, GROSS 180.32, NET -91.87
# 2017-07-03, BUY EXECUTED, Price: 2431.39, Size: 56, Cost: 136157.84, Comm 136.16, RemSize: 0, RemCash: 8749.33
# 2017-07-13, SELL EXECUTED, Price: 2444.99, Size: -56, Cost: 136157.84, Comm 136.92, RemSize: 0, RemCash: 145531.85
# 2017-07-13, OPERATION PROFIT, GROSS 761.60, NET 488.52
# 2017-07-18, SELL EXECUTED, Price: 2455.88, Size: -56, Cost: -137529.28, Comm 137.53, RemSize: 0, RemCash: 282923.60
# 2017-08-11, BUY EXECUTED, Price: 2441.04, Size: 56, Cost: -137529.28, Comm 136.70, RemSize: 0, RemCash: 146088.66
# 2017-08-11, OPERATION PROFIT, GROSS 831.04, NET 556.81
# 2017-08-15, BUY EXECUTED, Price: 2468.66, Size: 56, Cost: 138244.96, Comm 138.24, RemSize: 0, RemCash: 7705.46
# 2017-08-31, SELL EXECUTED, Price: 2462.65, Size: -56, Cost: 138244.96, Comm 137.91, RemSize: 0, RemCash: 145475.95
# 2017-08-31, OPERATION PROFIT, GROSS -336.56, NET -612.71
# 2017-09-14, SELL EXECUTED, Price: 2494.56, Size: -55, Cost: -137200.80, Comm 137.20, RemSize: 0, RemCash: 282539.55
# 2017-11-16, BUY EXECUTED, Price: 2572.95, Size: 55, Cost: -137200.80, Comm 141.51, RemSize: 0, RemCash: 140885.79
# 2017-11-16, OPERATION PROFIT, GROSS -4311.45, NET -4590.16
# 2017-12-05, SELL EXECUTED, Price: 2639.78, Size: -50, Cost: -131989.00, Comm 131.99, RemSize: 0, RemCash: 272742.80
# 2018-02-05, BUY EXECUTED, Price: 2741.06, Size: 50, Cost: -131989.00, Comm 137.05, RemSize: 0, RemCash: 135552.75
# 2018-02-05, OPERATION PROFIT, GROSS -5064.00, NET -5333.04
# 2018-02-07, BUY EXECUTED, Price: 2690.95, Size: 47, Cost: 126474.65, Comm 126.47, RemSize: 0, RemCash: 8951.62
# 2018-02-26, SELL EXECUTED, Price: 2757.37, Size: -47, Cost: 126474.65, Comm 129.60, RemSize: 0, RemCash: 138418.41
# 2018-02-26, OPERATION PROFIT, GROSS 3121.74, NET 2865.67
# 2018-03-27, BUY EXECUTED, Price: 2667.57, Size: 49, Cost: 130710.93, Comm 130.71, RemSize: 0, RemCash: 7576.77
# 2018-04-13, SELL EXECUTED, Price: 2676.90, Size: -49, Cost: 130710.93, Comm 131.17, RemSize: 0, RemCash: 138613.71
# 2018-04-13, OPERATION PROFIT, GROSS 457.17, NET 195.29
# 2018-05-14, SELL EXECUTED, Price: 2738.47, Size: -48, Cost: -131446.56, Comm 131.45, RemSize: 0, RemCash: 269928.82
# 2018-05-30, BUY EXECUTED, Price: 2702.43, Size: 48, Cost: -131446.56, Comm 129.72, RemSize: 0, RemCash: 140082.46
# 2018-05-30, OPERATION PROFIT, GROSS 1729.92, NET 1468.76
# 2018-06-12, SELL EXECUTED, Price: 2785.60, Size: -47, Cost: -130923.20, Comm 130.92, RemSize: 0, RemCash: 270874.74
# 2018-06-22, BUY EXECUTED, Price: 2760.79, Size: 47, Cost: -130923.20, Comm 129.76, RemSize: 0, RemCash: 140987.85
# 2018-06-22, OPERATION PROFIT, GROSS 1166.07, NET 905.39
# 2018-06-29, BUY EXECUTED, Price: 2727.13, Size: 49, Cost: 133629.37, Comm 133.63, RemSize: 0, RemCash: 7224.85
# 2018-07-09, SELL EXECUTED, Price: 2775.62, Size: -49, Cost: 133629.37, Comm 136.01, RemSize: 0, RemCash: 143094.23
# 2018-07-09, OPERATION PROFIT, GROSS 2376.01, NET 2106.38
# 2018-08-09, SELL EXECUTED, Price: 2857.19, Size: -47, Cost: -134287.93, Comm 134.29, RemSize: 0, RemCash: 277247.87
# 2018-08-14, BUY EXECUTED, Price: 2827.88, Size: 47, Cost: -134287.93, Comm 132.91, RemSize: 0, RemCash: 144204.60
# 2018-08-14, OPERATION PROFIT, GROSS 1377.57, NET 1110.37
# 2018-08-31, SELL EXECUTED, Price: 2898.37, Size: -47, Cost: -136223.39, Comm 136.22, RemSize: 0, RemCash: 280291.77
# 2018-10-05, BUY EXECUTED, Price: 2902.54, Size: 47, Cost: -136223.39, Comm 136.42, RemSize: 0, RemCash: 143735.97
# 2018-10-05, OPERATION PROFIT, GROSS -195.99, NET -468.63
# 2018-10-17, BUY EXECUTED, Price: 2811.67, Size: 48, Cost: 134960.16, Comm 134.96, RemSize: 0, RemCash: 8640.85
# 2018-11-07, SELL EXECUTED, Price: 2774.13, Size: -48, Cost: 134960.16, Comm 133.16, RemSize: 0, RemCash: 141665.93
# 2018-11-07, OPERATION PROFIT, GROSS -1801.92, NET -2070.04
# 2018-12-19, BUY EXECUTED, Price: 2547.05, Size: 52, Cost: 132446.60, Comm 132.45, RemSize: 0, RemCash: 9086.88
# 2019-01-08, SELL EXECUTED, Price: 2568.11, Size: -52, Cost: 132446.60, Comm 133.54, RemSize: 0, RemCash: 142495.06
# 2019-01-08, OPERATION PROFIT, GROSS 1095.12, NET 829.13
# 2019-03-20, SELL EXECUTED, Price: 2831.34, Size: -47, Cost: -133072.98, Comm 133.07, RemSize: 0, RemCash: 275434.97
# 2019-03-26, BUY EXECUTED, Price: 2812.66, Size: 47, Cost: -133072.98, Comm 132.20, RemSize: 0, RemCash: 143107.75
# 2019-03-26, OPERATION PROFIT, GROSS 877.96, NET 612.69
# 2019-04-09, SELL EXECUTED, Price: 2886.58, Size: -46, Cost: -132782.68, Comm 132.78, RemSize: 0, RemCash: 275757.65
# 2019-05-08, BUY EXECUTED, Price: 2879.61, Size: 46, Cost: -132782.68, Comm 132.46, RemSize: 0, RemCash: 143163.13
# 2019-05-08, OPERATION PROFIT, GROSS 320.62, NET 55.38
# 2019-05-16, BUY EXECUTED, Price: 2855.80, Size: 47, Cost: 134222.60, Comm 134.22, RemSize: 0, RemCash: 8806.30
# 2019-06-07, SELL EXECUTED, Price: 2852.87, Size: -47, Cost: 134222.60, Comm 134.08, RemSize: 0, RemCash: 142757.11
# 2019-06-07, OPERATION PROFIT, GROSS -137.71, NET -406.02
# 2019-07-08, SELL EXECUTED, Price: 2979.77, Size: -45, Cost: -134089.65, Comm 134.09, RemSize: 0, RemCash: 276712.67
# 2019-08-01, BUY EXECUTED, Price: 2980.32, Size: 45, Cost: -134089.65, Comm 134.11, RemSize: 0, RemCash: 142464.16
# 2019-08-01, OPERATION PROFIT, GROSS -24.75, NET -292.95
# 2019-08-08, BUY EXECUTED, Price: 2896.21, Size: 46, Cost: 133225.66, Comm 133.23, RemSize: 0, RemCash: 9105.27
# 2019-08-23, SELL EXECUTED, Price: 2911.07, Size: -46, Cost: 133225.66, Comm 133.91, RemSize: 0, RemCash: 142880.58
# 2019-08-23, OPERATION PROFIT, GROSS 683.56, NET 416.43
# 2019-09-09, SELL EXECUTED, Price: 2988.43, Size: -45, Cost: -134479.35, Comm 134.48, RemSize: 0, RemCash: 277225.45
# 2019-09-25, BUY EXECUTED, Price: 2968.35, Size: 45, Cost: -134479.35, Comm 133.58, RemSize: 0, RemCash: 143516.13
# 2019-09-25, OPERATION PROFIT, GROSS 903.60, NET 635.54
# 2019-10-07, BUY EXECUTED, Price: 2944.23, Size: 46, Cost: 135434.58, Comm 135.43, RemSize: 0, RemCash: 7946.11
# 2019-10-14, SELL EXECUTED, Price: 2965.81, Size: -46, Cost: 135434.58, Comm 136.43, RemSize: 0, RemCash: 144236.94
# 2019-10-14, OPERATION PROFIT, GROSS 992.68, NET 720.82
# 2019-12-02, SELL EXECUTED, Price: 3143.85, Size: -43, Cost: -135185.55, Comm 135.19, RemSize: 0, RemCash: 279287.31
# 2019-12-04, BUY EXECUTED, Price: 3103.50, Size: 43, Cost: -135185.55, Comm 133.45, RemSize: 0, RemCash: 145703.36
# 2019-12-04, OPERATION PROFIT, GROSS 1735.05, NET 1466.41
# 2019-12-16, SELL EXECUTED, Price: 3183.63, Size: -43, Cost: -136896.09, Comm 136.90, RemSize: 0, RemCash: 282462.55
# 2019-12-30, ROI: 43.95%
# 2019-12-30, (Bollinger params (20,  2)) Ending Value 143947.08
# Final Portfolio Value: 143947.08, Sharpe Ratio: 0.49, DrawDown: 2.95, MoneyDown 4379.08
# <div id='b537bf2a-506b-43e2-b81b-be459c70d91f'></div>
